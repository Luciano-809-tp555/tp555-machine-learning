# %%
# Import all necessary libraries
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib
from pylab import *
import numpy as np
import random

#%matplotlib notebook
#%matplotlib widget

# %%
N = 100

# Input values (features)
x = 10.0*np.random.rand(N, 1)

# Output values (targets).
y = 0.2 + 3.0*x + np.random.randn(N, 1)

# Plot features (input) versus targets (output)
fig = plt.figure(figsize=(10,10))
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x,y,'.')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Generate values for parameters.
a0 = np.linspace(-10.0, 10.0, 100)
a1 = np.linspace(-10.0, 10.0, 100)

A0, A1 = np.meshgrid(a0, a1)

J = np.zeros((100,100))
for iter0 in range(0, 100):
    
    for iter1 in range(0, 100):
        
        yhat = a0[iter0] + a1[iter1]*x
    
        J[iter0][iter1] = (1/N)*np.sum( np.power((y - yhat), 2)  );
        

# Plot Error surface.        
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(A0, A1, J, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

ax.set_xlabel('a0')
ax.set_ylabel('a1')
ax.set_zlabel('J');

ax.view_init(0, 90)
fig

#Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
fig = plt.figure(figsize=(10,10))

cp = plt.contour(A0, A1, J)
plt.clabel(cp, inline=1, fontsize=10)
plt.xlabel('a0')
plt.ylabel('a1')
plt.xticks(np.arange(-10, 12, step=2.0))
plt.yticks(np.arange(-10, 12, step=2.0))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Choosing values for a0 and a1.

a0 = -10.0;
a1 = -10.0;

yhat = a0 + a1*x

fig = plt.figure(figsize=(10,10))
plt.plot(x,yhat,'r')
plt.plot(x,y,'.')
plt.xlabel('x')
plt.ylabel('y')
plt.show()


yhat = a0 + a1*x;
Jlocal1 = (1/N)*np.sum( np.square(y - yhat)  );
print('Error J: ' + str(Jlocal))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Error J: 1.0419685222829926

# %%
# Choosing values for a0 and a1.

a0 = -4.0;
a1 = -4.0;

yhat = a0 + a1*x

fig = plt.figure(figsize=(10,10))
plt.plot(x,yhat,'r')
plt.plot(x,y,'.')
plt.xlabel('x')
plt.ylabel('y')

plt.title('Check Hypothesis') 
plt.legend(['Hypothesis', 'Actual Data'])

plt.show()

yhat = a0 + a1*x;
Jlocal2 = (1/N)*np.sum( np.square(y - yhat)  );
print('Error J: ' + str(Jlocal))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Error J: 1.0419685222829926

# %%
# Choosing values for a0 and a1.

a0 = -2.0;
a1 = -2.0;

yhat = a0 + a1*x

fig = plt.figure(figsize=(10,10))
plt.plot(x,yhat,'r')
plt.plot(x,y,'.')
plt.xlabel('x')
plt.ylabel('y')


plt.title('Check Hypothesis') 
plt.legend(['Hypothesis', 'Actual Data'])

plt.show()

yhat = a0 + a1*x;
Jlocal3 = (1/N)*np.sum( np.square(y - yhat)  );
print('Error J: ' + str(Jlocal))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Error J: 1.0419685222829926

# %%
# Choosing values for a0 and a1.

a0 = 1.0;
a1 = 1.0;

yhat = a0 + a1*x

fig = plt.figure(figsize=(10,10))
plt.plot(x,yhat,'r')
plt.plot(x,y,'.')
plt.xlabel('x')
plt.ylabel('y')


plt.title('Check Hypothesis') 
plt.legend(['Hypothesis', 'Actual Data'])

plt.show()

yhat = a0 + a1*x;
Jlocal4 = (1/N)*np.sum( np.square(y - yhat)  );
print('Error J: ' + str(Jlocal))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Error J: 1.0419685222829926

# %%
# Choosing values for a0 and a1.

a0 = 0.2;
a1 = 3.0;

yhat = a0 + a1*x

fig = plt.figure(figsize=(10,10))
plt.plot(x,yhat,'r')
plt.plot(x,y,'.')
plt.xlabel('x')
plt.ylabel('y')


plt.title('Check Hypothesis') 
plt.legend(['Hypothesis', 'Actual Data'])

plt.show()

yhat = a0 + a1*x;
Jlocal5 = (1/N)*np.sum( np.square(y - yhat)  );
print('Error J: ' + str(Jlocal))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Error J: 1.0419685222829926

# %%
# Plot Error surface.        
fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')

surf = ax.plot_surface(A0, A1, J, cmap=cm.coolwarm, linewidth=0, antialiased=False)
plt.plot(np.array([-10.0, -4.0, -2.0, 1.0, 0.2]), np.array([-10.0, -4.0, -2.0, 1.0, 3.0]), np.array([Jlocal1, Jlocal2, Jlocal3, Jlocal4, Jlocal5]), color='green')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

ax.set_xlabel('a0')
ax.set_ylabel('a1')
ax.set_zlabel('J');

ax.view_init(0, 90)
fig

#Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
