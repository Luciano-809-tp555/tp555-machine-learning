# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('sythquad.csv', header=None)

x = df[0].to_numpy()
y = df[1].to_numpy()

fig = plt.figure(figsize=(10,10))
plt.plot(x, y, 'b.')
