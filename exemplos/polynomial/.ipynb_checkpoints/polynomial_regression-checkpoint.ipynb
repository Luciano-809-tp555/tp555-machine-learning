# %%
# Import all the necessary libraries.
import numpy as np
import matplotlib.pyplot as plt
import math
# Import class PolynomialFeatures.
from sklearn.preprocessing import PolynomialFeatures
# Import class LinearRegression.
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# magic Jupyter function that allows plots to be interactive.
# %matplotlib notebook

# %%
# Sets the number of examples.
M = 20

np.random.seed(42)

# Create target function.
x1 = np.linspace(-3, 3, M).reshape(M, 1)
y = 2 + x1 + 0.5*x1**2;
y_noisy = y + np.random.randn(M, 1)

# %%
# Plot cost-function surface.
fig = plt.figure(figsize=(5,5))
plt.plot(x1, y, label='Dado original')
plt.plot(x1, y_noisy, 'x', label='Dado ruidoso')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.legend()
plt.grid()
#Show the plot.
plt.show()

# %%
# Instantiate a degree 1 polynomial.
poly_features = PolynomialFeatures(degree=1, include_bias=True)
# Instantiate a scaler.
std_scaler = StandardScaler()
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("std_scaler", std_scaler),
    ("lin_reg", lin_reg),
])

# Perform polynomial regression.
polynomial_regression.fit(x1, y_noisy)

# Use the trained model for prediction.
yp1 = polynomial_regression.predict(x1)

fig = plt.figure(figsize=(5,5))
plt.plot(x1, y, label='Dado original')
plt.plot(x1, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x1, yp1, label='Polinômio de ordem=1')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.grid()
plt.legend()

plt.savefig("polinomio1.png", dpi=600)

# %%
# Instantiate a degree 2 polynomial.
poly_features = PolynomialFeatures(degree=2, include_bias=True)
# Instantiate a scaler.
std_scaler = StandardScaler()
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("std_scaler", std_scaler),
    ("lin_reg", lin_reg),
])

# Perform polynomial regression.
polynomial_regression.fit(x1, y_noisy)

# Use the trained model for prediction.
yp2 = polynomial_regression.predict(x1)

fig = plt.figure(figsize=(5,5))
plt.plot(x1, y, label='Dado original')
plt.plot(x1, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x1, yp2, label='Polinômio de ordem=2')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.grid()
plt.legend()

plt.savefig("polinomio2.png", dpi=600)

# %%
# Instantiate a degree 10 polynomial.
poly_features = PolynomialFeatures(degree=10, include_bias=True)
# Instantiate a scaler.
std_scaler = StandardScaler()
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("std_scaler", std_scaler),
    ("lin_reg", lin_reg),
])

# Perform polynomial regression.
polynomial_regression.fit(x1, y_noisy)

# Use the trained model for prediction.
yp10 = polynomial_regression.predict(x1)

fig = plt.figure(figsize=(5,5))
plt.plot(x1, y, label='Dado original')
plt.plot(x1, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x1, yp10, label='Polinômio de ordem=10')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.grid()
plt.legend()

plt.savefig("polinomio10.png", dpi=600)

# %%
# Instantiate a degree 20 polynomial.
poly_features = PolynomialFeatures(degree=20, include_bias=True)
# Instantiate a scaler.
std_scaler = StandardScaler()
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("std_scaler", std_scaler),
    ("lin_reg", lin_reg),
])

# Perform polynomial regression.
polynomial_regression.fit(x1, y_noisy)

# Use the trained model for prediction.
yp20 = polynomial_regression.predict(x1)

fig = plt.figure(figsize=(5,5))
plt.plot(x1, y, label='Dado original')
plt.plot(x1, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x1, yp20, label='Polinômio de ordem=20')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.grid()
plt.legend()

plt.savefig("polinomio20.png", dpi=600)

# %%
# Instantiate a degree 30 polynomial.
poly_features = PolynomialFeatures(degree=30, include_bias=True)
# Instantiate a scaler.
std_scaler = StandardScaler()
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("std_scaler", std_scaler),
    ("lin_reg", lin_reg),
])

# Perform polynomial regression.
polynomial_regression.fit(x1, y_noisy)

# Use the trained model for prediction.
yp30 = polynomial_regression.predict(x1)

fig = plt.figure(figsize=(5,5))
plt.plot(x1, y, label='Dado original')
plt.plot(x1, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x1, yp30, label='Polinômio de ordem=30')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.grid()
plt.legend()

plt.savefig("polinomio30.png", dpi=600)

# %%
# Example set size.
M = 100

np.random.seed(42)

# Create target function.
x1 = np.linspace(-3, 3, M).reshape(M, 1)
y = 2 + x1 + 0.5*x1**2;
y_noisy = y + np.random.randn(M, 1)  

x1_train, x1_val, y_train, y_val = train_test_split(x1, y_noisy, test_size=0.2, random_state=10)

# Instantiate a degree 1 polynomial.
poly_features = PolynomialFeatures(degree=1, include_bias=True)
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("lin_reg", lin_reg),
])

error_training = []
error_validation = []
for m in range(1,len(x1_train)+1):

    # Perform polynomial regression.
    polynomial_regression.fit(x1_train[:m], y_train[:m])

    # Use the trained model for prediction of the training set.
    y_train_predict = polynomial_regression.predict(x1_train[:m])
    
    # Use the trained model for prediction of the validation set.
    y_val_predict = polynomial_regression.predict(x1_val)
    
    # Calculate MSE for training set.
    error_training.append(mean_squared_error(y_train[:m], y_train_predict))
    
    # Calculate MSE for validation set.
    error_validation.append(mean_squared_error(x1_val, y_val_predict))

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_training), label='Conjunto de treinamento')
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_validation), label='Conjunto de validação')
#plt.yscale('log')
plt.xlabel('Tamanho do conjunto de treinamento', fontsize=14)
plt.ylabel('Raiz Quadrada do Erro Quadrático Médio', fontsize=14)
plt.axis([0, 80, 0, 8])
plt.grid()
plt.title('Polinômio de ordem 1')
plt.legend()

# %%
# Instantiate a degree 2 polynomial.
poly_features = PolynomialFeatures(degree=2, include_bias=True)
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("lin_reg", lin_reg),
])

error_training = []
error_validation = []
for m in range(1,len(x1_train)+1):

    # Perform polynomial regression.
    polynomial_regression.fit(x1_train[:m], y_train[:m])

    # Use the trained model for prediction of the training set.
    y_train_predict = polynomial_regression.predict(x1_train[:m])
    
    # Use the trained model for prediction of the validation set.
    y_val_predict = polynomial_regression.predict(x1_val)
    
    # Calculate MSE for training set.
    error_training.append(mean_squared_error(y_train[:m], y_train_predict))
    
    # Calculate MSE for validation set.
    error_validation.append(mean_squared_error(x1_val, y_val_predict))

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_training), label='Conjunto de treinamento')
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_validation), label='Conjunto de validação')
#plt.yscale('log')
plt.xlabel('Tamanho do conjunto de treinamento', fontsize=14)
plt.ylabel('Raiz Quadrada do Erro Quadrático Médio', fontsize=14)
plt.axis([0, 80, 0, 8])
plt.grid()
plt.title('Polinômio de ordem 2')
plt.legend()

# %%
# Instantiate a degree 3 polynomial.
poly_features = PolynomialFeatures(degree=3, include_bias=True)
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("lin_reg", lin_reg),
])

error_training = []
error_validation = []
for m in range(1,len(x1_train)+1):

    # Perform polynomial regression.
    polynomial_regression.fit(x1_train[:m], y_train[:m])

    # Use the trained model for prediction of the training set.
    y_train_predict = polynomial_regression.predict(x1_train[:m])
    
    # Use the trained model for prediction of the validation set.
    y_val_predict = polynomial_regression.predict(x1_val)
    
    # Calculate MSE for training set.
    error_training.append(mean_squared_error(y_train[:m], y_train_predict))
    
    # Calculate MSE for validation set.
    error_validation.append(mean_squared_error(x1_val, y_val_predict))

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_training), label='Conjunto de treinamento')
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_validation), label='Conjunto de validação')
#plt.yscale('log')
plt.xlabel('Tamanho do conjunto de treinamento', fontsize=14)
plt.ylabel('Raiz Quadrada do Erro Quadrático Médio', fontsize=14)
plt.axis([0, 80, 0, 8])
plt.grid()
plt.title('Polinômio de ordem 3')
plt.legend()

# %%
# Instantiate a degree 5 polynomial.
poly_features = PolynomialFeatures(degree=5, include_bias=True)
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("lin_reg", lin_reg),
])

error_training = []
error_validation = []
for m in range(1,len(x1_train)+1):

    # Perform polynomial regression.
    polynomial_regression.fit(x1_train[:m], y_train[:m])

    # Use the trained model for prediction of the training set.
    y_train_predict = polynomial_regression.predict(x1_train[:m])
    
    # Use the trained model for prediction of the validation set.
    y_val_predict = polynomial_regression.predict(x1_val)
    
    # Calculate MSE for training set.
    error_training.append(mean_squared_error(y_train[:m], y_train_predict))
    
    # Calculate MSE for validation set.
    error_validation.append(mean_squared_error(x1_val, y_val_predict))

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_training), label='Conjunto de treinamento')
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_validation), label='Conjunto de validação')
#plt.yscale('log')
plt.xlabel('Tamanho do conjunto de treinamento', fontsize=14)
plt.ylabel('Raiz Quadrada do Erro Quadrático Médio', fontsize=14)
plt.axis([0, 80, 0, 8])
plt.grid()
plt.title('Polinômio de ordem 5')
plt.legend()

# %%
# Instantiate a degree 80 polynomial.
poly_features = PolynomialFeatures(degree=80, include_bias=True)
# Instantiate a scaler.
std_scaler = StandardScaler()
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("std_scaler", std_scaler),
    ("lin_reg", lin_reg),
])

error_training = []
error_validation = []
for m in range(1,len(x1_train)+1):

    # Perform polynomial regression.
    polynomial_regression.fit(x1_train[:m], y_train[:m])

    # Use the trained model for prediction of the training set.
    y_train_predict = polynomial_regression.predict(x1_train[:m])
    
    # Use the trained model for prediction of the validation set.
    y_val_predict = polynomial_regression.predict(x1_val)
    
    # Calculate MSE for training set.
    error_training.append(mean_squared_error(y_train[:m], y_train_predict))
    
    # Calculate MSE for validation set.
    error_validation.append(mean_squared_error(x1_val, y_val_predict))

# %%
fig = plt.figure(figsize=(6,6))
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_training), label='Conjunto de treinamento')
plt.plot(range(1,len(x1_train)+1), np.sqrt(error_validation), label='Conjunto de validação')
plt.yscale('log')
plt.xlabel('Tamanho do conjunto de treinamento', fontsize=14)
plt.ylabel('Raiz Quadrada do Erro Quadrático Médio', fontsize=14)
plt.xlim([1, 80])
plt.grid()
plt.title('Polinômio de ordem 80')
plt.legend()

# %%
# Example set size.
M = 100

np.random.seed(42)

# Create target function.
x1 = np.linspace(-3, 3, M).reshape(M, 1)
y = 2 + x1 + 0.5*x1**2;
y_noisy = y + np.random.randn(M, 1)  

# Instantiate a degree 80 polynomial.
poly_features = PolynomialFeatures(degree=80, include_bias=True)
# Instantiate a scaler.
std_scaler = StandardScaler()
# Instantiate a linear regressor.
lin_reg = LinearRegression()

# Create a pipeline of actions.
polynomial_regression = Pipeline([
    ("poly_features", poly_features),
    ("std_scaler", std_scaler),
    ("lin_reg", lin_reg),
])

# Perform polynomial regression.
polynomial_regression.fit(x1, y_noisy)

# Use the trained model for prediction of the training set.
y_train_predict = polynomial_regression.predict(x1)

fig = plt.figure(figsize=(6,6))
plt.plot(x1, y, label='Dado original')
plt.plot(x1, y_noisy, 'x', label='Dado ruidoso')
plt.plot(x1, y_train_predict, label='Polinômio de ordem=80')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$y$', fontsize=14)
plt.grid()
plt.legend()

plt.savefig("polinomio80.png", dpi=600)
